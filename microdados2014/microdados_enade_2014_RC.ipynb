# %% [markdown]
# [![](https://enade.inep.gov.br/enade/images/logo.png "Resultados")](https://www.gov.br/inep/pt-br/areas-de-atuacao/avaliacao-e-exames-educacionais/enade/resultados)
#
# * Conceito Enade 2014 ([xlsx](https://download.inep.gov.br/educacao_superior/enade/planilhas/2014/conceito_enade_2014_atualizado_em_04122017.xlsx) | [csv](https://download.inep.gov.br/educacao_superior/enade/planilhas/2014/conceito_enade_2014_atualizado_em_04122017.csv))
#
# * Microdados Enade 2014 ([zip](https://download.inep.gov.br/microdados/microdados_enade_2014_LGPD.zip))
#
# * Provas e Gabaritos do ano de 2014:
#   * Ciência da computação (bacharelado) ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2014/03_computacao_bacharelado.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2014/03_gab_computacao_bacharelado.pdf) | [Padrão de resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2014/padrao_resposta_ciencia_computacao_bacharelado.pdf) | [Relatório](http://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2014/2014_rel_ciencia_da_computacao.pdf))
#
#   * Sistemas de informação (bacharelado) ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2014/39_sistemas_informacao.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2014/39_gab_sistemas_informacao.pdf) | [Padrão de Resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2014/padrao_resposta_sistemas_informacao.pdf) | [Relatório](http://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2014/2014_rel_sistemas_de_informacao.pdf))
#
#   * Tecnologia em Redes de Computadores ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2014/43_tecnologia_redes_computadores.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2014/43_gab_tecnologia_redes_computadores.pdf) | [Padrão de Resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2014/padrao_resposta_tecnologia_em_redes_computadores.pdf) | [Relatório](http://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2014/2014_rel_tecnologia_em_redes_de_computadores.pdf))

# %% [markdown]
# ### **Coleta de dados**

# %%
#@title Realizar **download** do arquivo `microdados_enade_2014_LGPD.zip`
# !wget --no-check-certificate https://download.inep.gov.br/microdados/microdados_enade_2014_LGPD.zip
# !unzip microdados_enade_2014_LGPD.zip
# microdados2014_arq3 = "microdados_Enade_2014_LGPD/2.DADOS/microdados2014_arq3.txt"

# %%
#@title Realizar **upload** do arquivo `microdados2014_arq3.txt`

# from google.colab import files

# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# microdados2014_arq3 = "microdados2014_arq3.txt"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title **Escrever** arquivo `microdados2014_arq3.txt`
microdados2014_arq3 = "microdados2014_arq3.txt"
with open(microdados2014_arq3,"w+") as f:
"D"
2014;"106167";8;0;0;0;27;0;8;0;"ACEBDCED";"ABDADBAXXEXXBDXECBCCACXBCXX";"ADDBBCED";"10010111";"ABDADBAACEACADEBCACCACCBACE";"111111199199019010111191099";555;555;555;555;555;555;555;555;555;555;555;69.9;65.5;62.5;70;87;75;90;53;65;50;71.3;78.9;28.3;0;45;40;"B";"C";"B";"B";"B";"A";"D";"D";"D"
2014;"106167";8;0;0;0;27;0;8;0;"ACEBDCED";"ABDADBAXXEXXBDXECBCCACXBCXX";;;;;222;222;222;222;222;222;222;222;222;222;222;;;;;;;;;;;;;;;;;;;;;;;;;
2014;"106167";8;0;0;0;27;0;8;0;"ACEBDCED";"ABDADBAXXEXXBDXECBCCACXBCXX";;;;;222;222;222;222;222;222;222;222;222;222;222;;;;;;;;;;;;;;;;;;;;;;;;;
""")

# %% [markdown]
# ### **Análise dos Microdados**

# %%
#@title Selecione um curso ou insira um código de curso do INEP:

import pandas as pd
import numpy as np

CURSO = "TECNOLOGIA EM REDES DE COMPUTADORES - UFC - QUIXADA - 1127191" # @param ["TECNOLOGIA EM REDES DE COMPUTADORES - UFC - QUIXADA - 1127191"] {allow-input: true}
CURSO = int(CURSO.split(" - ")[-1])
CURSO

df = pd.read_csv(microdados2014_arq3,delimiter=';',dtype={'DS_VT_ACE_OFG':'object','DS_VT_ACE_OCE':'object'})
df = df[df.CO_CURSO == CURSO].sort_values(by=["NT_GER"]).reset_index(drop=True)
df

# %% [markdown]
# Filtrar colunas de interesse

# %%
df1 = df[['NU_ANO', 'CO_CURSO', 'NT_DIS_FG', 'NT_OBJ_FG', 'NT_FG', 'NT_DIS_CE', 'NT_OBJ_CE', 'NT_CE', 'NT_GER',
        'DS_VT_ESC_OFG', 'DS_VT_GAB_OFG_FIN', 'DS_VT_ACE_OFG', 'DS_VT_ESC_OCE', 'DS_VT_GAB_OCE_FIN', 'DS_VT_ACE_OCE',
        ]].dropna().sort_values(by=["NT_GER"]).reset_index(drop=True)
df1

# %% [markdown]
# # **Discursivas Específicas**

# %%
DfDis = df[['NT_CE_D1','NT_CE_D2','NT_CE_D3']]
DfDis

# %% [markdown]
# # **Objetivas**

# %%
# @title Questões Objetivas de FG e CE

df2 = pd.DataFrame(data=[list(v) for v in df1.DS_VT_ACE_OFG + df1.DS_VT_ACE_OCE],columns=[f'Q{x}' for x in range(1,36)]).astype('int32')
df2

# %%
# @title Frequêcncia de Erros/Acertos

df3 = df2.astype('object').describe().T
df3 = df3[df3.unique == 2][['top','freq']].sort_values(by=["top","freq"],ascending=False)
df3

# %% [markdown]
# ## **Temas e Disciplinas das Questões Objetivas Específicas**

# %%
# @title Download do arquivo `temas_objetivas_2014`

# !wget -p --no-check-certificate '/content/drive/' https://drive.google.com/file/d/1PnwA4u4rdaujlGtVboLzqeOGJm7gb2FK/view?usp=drive_link
# temas_objetivas_2014 = "temas_objetivas_2014.txt"

# %%
# @title Upload do arquivo `temas_objetivas_2014`

# from google.colab import files

# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
# temas_objetivas_2014 = "temas_objetivas_2014.txt"

# %%
# @title Escrever arquivo `temas_objetivas_2014`

temas_objetivas_2014 = "temas_objetivas_2014.txt"
with open(temas_objetivas_2014,"w+") as f:
        f.writelines("""numero_questao,tipo_questao,tema,disciplina
Q09,O,Fundamentos de Redes/Equipamentos para Interconexão de Redes,Redes de Computadores
Q10,O,Padrões e Protocolos Utilizados na Arquitetura TCP/IP,Internet e Arquitetura TCP/IP
Q11,O,Padrões e Protocolos Utilizados na Arquitetura TCP/IP,Internet e Arquitetura TCP/IP
Q12,O,Padrões para Redes Locais IEEE 802,Redes de Computadores
Q13,O,Equipamentos para Interconexão de Redes,Segurança da Informação
Q14,O,Fundamentos de Comunicação e Transmissão de Dados,Redes de Computadores
Q15,O,Segurança de Redes de Computadores,Redes de Comunicações Móveis/Segurança da Informação
Q16,O,Projeto de Redes de Computadores,Laboratório em Infraestrutura de Redes de Computadores
Q17,O,Padrões de Cabeamento Estruturado,Laboratório em Infraestrutura de Redes de Computadores
Q18,O,Sustentabilidade e Meio ambiente,Gestão de Tecnologia da Informação e Comunicação
Q19,O,Gerenciamento de Redes,Gerência de Redes
Q20,O,Administração de Sistemas Operacionais de Redes,Sistemas Operacionais
Q21,O,Administração de Sistemas Operacionais de Redes,Serviços de Redes
Q22,O,Gerenciamento de Redes,Gerência de Redes
Q23,O,Gerenciamento de Redes,Gerência de Redes
Q24,O,Redes Convergentes,Gestão de Tecnologia da Informação e Comunicação
Q25,O,Projeto de Redes de Computadores,Laboratório em Infraestrutura de Redes de Computadores/Gestão de Tecnologia da Informação e Comunicação
Q26,O,Ética e Empreendedorismo,"Ética, Direito e Legislação"
Q27,O,Tecnologias Emergentes,Tópicos Avançados em Redes de Computadores
Q28,O,Tecnologias Emergentes,Tópicos Avançados em Redes de Computadores
Q29,O,Padrões para Redes Locais IEEE 802,Redes de Comunicações Móveis
Q30,O,Padrões de Cabeamento Estruturado,Laboratório em Infraestrutura de Redes de Computadores
Q31,O,Projeto de Redes de Computadores,"Ética, Direito e Legislação"
Q32,O,Segurança de Redes de Computadores,Segurança da Informação
Q33,O,Redes de Longas Distâncias,Redes de Comunicações Móveis/Serviços de Redes
Q34,O,Padrões para Redes sem Fio,Redes de Comunicações Móveis
Q35,O,Gerenciamento de Redes,Gerência de Redes
""")

# %%
# @title **Mapeamento de Temas e Disciplinas das Questões Objetivas de CE**
dfTemas = pd.read_csv('/content/temas_objetivas_2014.txt', sep=",").dropna().reset_index(drop=True)
dfTemas

# %%
# @title Questões Objetivas de CE

dfObjEsp = pd.DataFrame(data=[list(i) for i in df1.DS_VT_ACE_OCE], columns=[f'Q{x}' for x in range(9,36)]).astype('int32')
dfObjEsp

# %%
# @title Frequência de Erros/Acertos

dfObjEspFreq = dfObjEsp.astype('object').describe().T
dfObjEspFreq = dfObjEspFreq[dfObjEspFreq.unique == 2][['top','freq']].sort_values(by=["top","freq"],ascending=False)
dfObjEspFreq

# %% [markdown]
# # **Questionário de Percepção da Prova**

# %%
dfPercep = df[['CO_RS_I1','CO_RS_I2','CO_RS_I3','CO_RS_I4','CO_RS_I5','CO_RS_I6','CO_RS_I7','CO_RS_I8','CO_RS_I9']].dropna().reset_index(drop=True)
dfPercep
