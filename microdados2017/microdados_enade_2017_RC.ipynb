# %% [markdown]
# [![](https://enade.inep.gov.br/enade/images/logo.png "Resultados")](https://www.gov.br/inep/pt-br/areas-de-atuacao/avaliacao-e-exames-educacionais/enade/resultados)
#
# * Conceito Enade 2017 ([xlsx](https://download.inep.gov.br/educacao_superior/indicadores/legislacao/2018/resultados_conceito_enade_2017.xlsx) | [csv](https://download.inep.gov.br/educacao_superior/indicadores/legislacao/2018/resultados_conceito_enade_2017.csv))
#
# * Microdados Enade 2017 ([zip](https://download.inep.gov.br/microdados/microdados_enade_2017_LGPD.zip))
#
# * Provas e Gabaritos do ano de 2017:
#   * Ciência da computação (bacharelado) ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2017/03_CIE_COM_BACHAREL_BAIXA.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2017/03_Ciencia_da_Computacao_Bacharelado.pdf) | [Padrão de resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2017/Pad_Resp_Ciencia_Computacao_bach.pdf) | [Relatório](https://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2017/Ciencia_da_Computacao.pdf))
#
#   * Sistemas de informação (bacharelado) ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2017/40_SIS_INFORMACAO_BAIXA.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2017/40_Sistemas_de_Informacao.pdf) | [Padrão de Resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2017/Pad_Resp_Sistemas_de_Informacao.pdf) | [Relatório](http://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2017/Sistema_de_Informacao.pdf))
#
#   * Tecnologia em Redes de Computadores ([Prova](http://download.inep.gov.br/educacao_superior/enade/provas/2017/44_TEC_RED_COM_BAIXA.pdf) | [Gabarito](http://download.inep.gov.br/educacao_superior/enade/gabaritos/2017/44_CST_em_Redes_de_Computadores.pdf) | [Padrão de Resposta](http://download.inep.gov.br/educacao_superior/enade/padrao_resposta/2017/Pad_Resp_CST_em_Redes_de_Computadores.pdf) | [Relatório](http://download.inep.gov.br/educacao_superior/enade/relatorio_sintese/2017/Tec_Redes_de_Computadores.pdf))

# %% [markdown]
# ### **Coleta dos dados**

# %%
#@title Realizar **download** do arquivo `microdados_enade_2017_LGPD.zip`
# !wget --no-check-certificate https://download.inep.gov.br/microdados/microdados_enade_2017_LGPD.zip
# !unzip microdados_enade_2017_LGPD.zip
# microdados2017_arq3 = "microdados_Enade_2017_LGPD/2.DADOS/microdados2017_arq3.txt"

# %%
#@title Realizar **upload** do arquivo `microdados2017_arq3.txt`

# from google.colab import files

# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# microdados2017_arq3 = "microdados2017_arq3.txt"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title **Escrever** arquivo `microdados2017_arq3.txt`
microdados2017_arq3 = "microdados2017_arq3.txt"
with open(microdados2017_arq3,"w+") as f:
        f.writelines(""""NU_ANO";"CO_CURSO";"NU_ITEM_OFG";"NU_ITEM_OFG_Z";"NU_ITEM_OFG_X";"NU_ITEM_OFG_N";"NU_ITEM_OCE";"NU_ITEM_OCE_Z";"NU_ITEM_OCE_X";"NU_ITEM_OCE_N";"DS_VT_GAB_OFG_FIN";"DS_VT_GAB_OCE_FIN";"DS_VT_ESC_OFG";"DS_VT_ACE_OFG";"DS_VT_ESC_OCE";"DS_VT_ACE_OCE";"TP_PRES";"TP_PR_GER";"TP_PR_OB_FG";"TP_PR_DI_FG";"TP_PR_OB_CE";"TP_P

2017;1270596;8;0;0;0;27;0;3;0;"CCBBCEAD";"ACECBCDEADEDXCAEXXBDEBEBDAE";"BCABEEED";"01010101";"AAEABCAEADEEECAEDABDDBAADAE";"101011011110911199110100111";555;555;555;555;555;555;555;555;555;555;555;64.5;52;50;55;95;75;100;15;75;0;68.7;70.8;56.7;70;80;20;"C";"C";"D";"D";"A";"B";"A";"D";"E"
2017;1270596;8;0;0;0;27;0;3;0;"CCBBCEAD";"ACECBCDEADEDXCAEXXBDEBEBDAE";"CCBBCEAD";"11111111";"AAEEBDCCADEDBCCEE..DDBEBDAB";"101010001111910199010111110";555;555;555;555;555;555;555;555;555;555;555;69.6;89;100;72.5;75;75;75;70;50;75;63.1;62.5;66.7;40;70;90;"D";"D";"B";"B";"B";"A";"A";"D";"D"
""")

# %% [markdown]
# ### **Análise dos microdados**

# %%
#@title Selecione um curso ou insira um código de curso do INEP:

import pandas as pd
import numpy as np

CURSO = "TECNOLOGIA EM REDES DE COMPUTADORES - UFC - QUIXADA - 1127191" #@param ["CIENCIA DA COMPUTACAO - UFC - QUIXADA - 1270596","SISTEMAS DE INFORMACAO - UFC - QUIXADA - 106167","TECNOLOGIA EM REDES DE COMPUTADORES - UFC - QUIXADA - 1127191"] {allow-input: true}
CURSO = int(CURSO.split(" - ")[-1])
CURSO

df = pd.read_csv(microdados2017_arq3,delimiter=';',dtype={'DS_VT_ACE_OFG':'object','DS_VT_ACE_OCE':'object'})
df = df[df.CO_CURSO == CURSO].sort_values(by=["NT_GER"]).reset_index(drop=True)
df

# %% [markdown]
# Filtrar colunas de interesse

# %%
df1 = df[['NU_ANO', 'CO_CURSO', 'NT_DIS_FG', 'NT_OBJ_FG', 'NT_FG', 'NT_DIS_CE', 'NT_OBJ_CE', 'NT_CE', 'NT_GER',
        'DS_VT_ESC_OFG', 'DS_VT_GAB_OFG_FIN', 'DS_VT_ACE_OFG', 'DS_VT_ESC_OCE', 'DS_VT_GAB_OCE_FIN', 'DS_VT_ACE_OCE',
        ]].dropna().sort_values(by=["NT_GER"]).reset_index(drop=True)
df1

# %% [markdown]
# # **Discursivas Específicas**

# %%
DfDis = df[['NT_CE_D1','NT_CE_D2','NT_CE_D3']]
DfDis

# %% [markdown]
# # **Objetivas**

# %%
# @title Questões Objetivas de FG e CE

df2 = pd.DataFrame(data=[list(v) for v in df1.DS_VT_ACE_OFG + df1.DS_VT_ACE_OCE],columns=[f'Q{x}' for x in range(1,36)]).astype('int32')
df2

# %%
# @title Frequêcncia de Erros/Acertos

df3 = df2.astype('object').describe().T
df3 = df3[df3.unique == 2][['top','freq']].sort_values(by=["top","freq"],ascending=False)
df3

# %% [markdown]
# ## **Temas e Disciplinas das Questões Objetivas Específicas**

# %%
# @title Download do arquivo `temas_objetivas_2017`

# !wget --no-check-certificate -p '/content/drive' https://drive.google.com/file/d/1KwrGjnSwNtRTaId0Zx9mX_RmuoXvYKM0/view?usp=drive_link
# temas_objetivas_2017 = temas_objetivas_2017.txt

# %%
# @title Upload do arquivo `temas_objetivas_2017`

# from google.colab import files

# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# temas_objetivas_2017 = temas_objetivas_2017.txt

# %%
# @title Escrever arquivo `temas_objetivas_2017`

temas_objetivas_2017 = "temas_objetivas_2017.txt"
with open(temas_objetivas_2017,"w+") as f:
        f.writelines("""numero_questao,tipo_questao,tema,disciplina
Q09,O,"Fundamentos, componentes e topologias de redes de computadores",Redes de Computadores/Internet e Arquitetura TCP/IP
Q10,O,Administração e gerenciamento de serviços de redes de computadores e virtualização,Tópicos Avançados em Redes de Computadores
Q11,O,Fundamentos da comunicação e transmissão de dados/modelos de referência de redes de computadores/arquitetura TCP/IP e seus protocolos,Redes de Computadores/Internet e Arquitetura TCP/IP
Q12,O,Modelos de referência de redes de computadores,Redes de Computadores
Q13,O,Arquitetura TCP/IP e seus protocolos,Internet e Arquitetura TCP/IP
Q14,O,Modelos e algoritmos de roteamento,Redes de Computadores
Q15,O,Padrões para redes sem fio e requisitos de segurança,Redes de Comunicações Móveis
Q16,O,Programação e banco de dados voltado para redes de computadores,Fundamentos de Banco de Dados
Q17,O,Segurança de redes de computadores,Segurança da Informação
Q18,O,Equipamentos para interconexão de redes de computadores,Redes de Computadores
Q19,O,Padrões para redes sem fio e requisitos de segurança,Redes de Comunicações Móveis
Q20,O,Protocolos de redes de longa distância/Redes convergentes,Serviços de Redes
Q21,O,Programação e banco de dados voltado para redes de computadores/Segurança de redes de computadores,Segurança da Informação
Q22,O,Segurança de redes de computadores,Administração de Sistemas Operacionais Windows/Linux
Q23,O,Governança corporativa e auditoria,Gerência de Projetos
Q24,O,Arquitetura TCP/IP e seus protocolos,Internet e Arquitetura TCP/IP
Q25,O,Redes convergentes/Protocolos de redes de longa distância,Serviços de Redes
Q26,O,Governança corporativa e auditoria,Gestão de Tecnologia da Informação e Comunicação
Q27,O,Fundamentos da comunicação e transmissão de dados,Redes de Computadores
Q28,O,Redes convergentes/Protocolos de redes de longa distância,Serviços de Redes
Q29,O,Arquitetura TCP/IP e seus protocolos/Redes convergentes/Protocolos de redes de longa distância,Serviços de Redes
Q30,O,Governança corporativa e auditoria,Gestão de Tecnologia da Informação e Comunicação
Q31,O,Fundamentos da comunicação e transmissão de dados/Normas e padrões de cabeamento estruturado,Laboratório em Infraestrutura de Redes de Computadores
Q32,O,Tecnologias emergentes,Tópicos Avançados em Redes de Computadores
Q33,O,Tecnologias emergentes,Tópicos Avançados em Redes de Computadores
Q34,O,Tecnologias emergentes,Gestão de Tecnologia da Informação e Comunicação
Q35,O,Tecnologias emergentes,Tópicos Avançados em Redes de Computadores""")

# %%
# @title **Mapeamento de Temas e Disciplinas das Questões Objetivas de CE**

dfTemas = pd.read_csv('/content/temas_objetivas_2017.txt', sep=",").dropna().reset_index(drop=True)
dfTemas

# %%
# @title Questões Objetivas de CE

dfObjEsp = pd.DataFrame(data=[list(i) for i in df1.DS_VT_ACE_OCE], columns=[f'Q{x}' for x in range(9,36)]).astype('int32')
dfObjEsp

# %%
# @title Frequência de Erros/Acertos

dfObjEspFreq = dfObjEsp.astype('object').describe().T
dfObjEspFreq = dfObjEspFreq[dfObjEspFreq.unique == 2][['top','freq']].sort_values(by=["top","freq"],ascending=False)
dfObjEspFreq

# %% [markdown]
# # **Questionário de Percepção da Prova**

# %%
dfPercep = df[['CO_RS_I1','CO_RS_I2','CO_RS_I3','CO_RS_I4','CO_RS_I5','CO_RS_I6','CO_RS_I7','CO_RS_I8','CO_RS_I9']].dropna().reset_index(drop=True)
dfPercep
